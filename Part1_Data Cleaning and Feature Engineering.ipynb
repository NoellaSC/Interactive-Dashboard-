# %% [markdown]
# # PART - 1 - Data Cleaning and Feature Engineering

# %%
import pandas as pd

# %% [markdown]
# ## read csv files of world happiness report dataset 2020, 2021, and 2022

# %%
y22 = pd.read_csv('2022.csv')
y22
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low
# 0       1      Finland           7,821        7,886       7,756  \
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
# 146   147           xx             NaN          NaN         NaN
#
#     Dystopia (1.83) + residual Explained by: GDP per capita
# 0                        2,518                        1,892  \
# 1                        2,226                        1,953
# ...

# %%
y21 = pd.read_csv('2021.csv')
y21
# Out:
#     Country name  Regional indicator  Ladder score
# 0        Finland      Western Europe         7.842  \
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker
# 0                             0.032         7.904         7.780  \
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
y20 = pd.read_csv('2020.csv')
y20
# Out:
#                  Country name  Regional indicator  Ladder score
# 0                     Finland      Western Europe        7.8087  \
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker
# 0                          0.031156      7.869766      7.747634  \
# 1                          0.033492      7.711245      7.579955
# ...

# %% [markdown]
# ## working on 2022 dataset

# %%
y22.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
#check NaN
y22.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               1
# Whisker-high                                  1
# Whisker-low                                   1
# Dystopia (1.83) + residual                    1
# Explained by: GDP per capita                  1
# Explained by: Social support                  1
# Explained by: Healthy life expectancy         1
# Explained by: Freedom to make life choices    1
# Explained by: Generosity                      1
# Explained by: Perceptions of corruption       1
# dtype: int64

# %%
#drop NaN
y22 = y22.dropna()
y22
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low
# 0       1      Finland           7,821        7,886       7,756  \
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 141   142    Botswana*           3,471        3,667       3,275
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita
# 0                        2,518                        1,892  \
# 1                        2,226                        1,953
# ...

# %%
#check again
y22.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
# clear unwated string
y22 = y22[~y22['Country'].str.contains('\*')]
y22
# Out:
#      RANK       Country Happiness score Whisker-high Whisker-low
# 0       1       Finland           7,821        7,886       7,756  \
# 1       2       Denmark           7,636        7,710       7,563
# 2       3       Iceland           7,557        7,651       7,464
# 3       4   Switzerland           7,512        7,586       7,437
# 4       5   Netherlands           7,415        7,471       7,359
# ..    ...           ...             ...          ...         ...
# 138   139      Tanzania           3,702        3,847       3,558
# 139   140  Sierra Leone           3,574        3,732       3,416
# 143   144      Zimbabwe           2,995        3,110       2,880
# 144   145       Lebanon           2,955        3,049       2,862
# 145   146   Afghanistan           2,404        2,469       2,339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita
# 0                        2,518                        1,892  \
# 1                        2,226                        1,953
# ...

# %%
# replace string for better undersanding
y22 = y22.replace(',', '.', regex=True)
y22
# Out:
#      RANK       Country Happiness score Whisker-high Whisker-low
# 0       1       Finland           7.821        7.886       7.756  \
# 1       2       Denmark           7.636        7.710       7.563
# 2       3       Iceland           7.557        7.651       7.464
# 3       4   Switzerland           7.512        7.586       7.437
# 4       5   Netherlands           7.415        7.471       7.359
# ..    ...           ...             ...          ...         ...
# 138   139      Tanzania           3.702        3.847       3.558
# 139   140  Sierra Leone           3.574        3.732       3.416
# 143   144      Zimbabwe           2.995        3.110       2.880
# 144   145       Lebanon           2.955        3.049       2.862
# 145   146   Afghanistan           2.404        2.469       2.339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita
# 0                        2.518                        1.892  \
# 1                        2.226                        1.953
# ...

# %%
y22 = y22.replace('Czechia', 'Czech Republic', regex=True)
y22
# Out:
#      RANK       Country Happiness score Whisker-high Whisker-low
# 0       1       Finland           7.821        7.886       7.756  \
# 1       2       Denmark           7.636        7.710       7.563
# 2       3       Iceland           7.557        7.651       7.464
# 3       4   Switzerland           7.512        7.586       7.437
# 4       5   Netherlands           7.415        7.471       7.359
# ..    ...           ...             ...          ...         ...
# 138   139      Tanzania           3.702        3.847       3.558
# 139   140  Sierra Leone           3.574        3.732       3.416
# 143   144      Zimbabwe           2.995        3.110       2.880
# 144   145       Lebanon           2.955        3.049       2.862
# 145   146   Afghanistan           2.404        2.469       2.339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita
# 0                        2.518                        1.892  \
# 1                        2.226                        1.953
# ...

# %%
# add Regional indicator in 2022 file

# %%
#check the Regional indicator columns in 2021 flie
unique_regional = y21['Regional indicator'].unique()
unique_regional
# Out:
# array(['Western Europe', 'North America and ANZ',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
y21_region=y21[['Country name', 'Regional indicator']]
print(y21_region)
# Out:
#     Country name  Regional indicator
# 0        Finland      Western Europe
# 1        Denmark      Western Europe
# 2    Switzerland      Western Europe
# 3        Iceland      Western Europe
# 4    Netherlands      Western Europe
# ..           ...                 ...
# 144      Lesotho  Sub-Saharan Africa
# 145     Botswana  Sub-Saharan Africa
# 146       Rwanda  Sub-Saharan Africa
# 147     Zimbabwe  Sub-Saharan Africa
# 148  Afghanistan          South Asia
#
# [149 rows x 2 columns]

# %%
# group the dataframe by regional indicator
grouped = y21_region.groupby('Regional indicator')

# print the group lists
for name, group in grouped:
    print(name)
    print(group['Country name'].tolist())
    print()
# Out:
# Central and Eastern Europe
# ['Czech Republic', 'Slovenia', 'Kosovo', 'Slovakia', 'Lithuania', 'Estonia', 'Poland', 'Romania', 'Serbia', 'Latvia', 'Hungary', 'Croatia', 'Bosnia and Herzegovina', 'Montenegro', 'Bulgaria', 'Albania', 'North Macedonia']
#
# Commonwealth of Independent States
# ['Uzbekistan', 'Kazakhstan', 'Moldova', 'Kyrgyzstan', 'Belarus', 'Russia', 'Tajikistan', 'Armenia', 'Azerbaijan', 'Turkmenistan', 'Georgia', 'Ukraine']
#
# East Asia
# ['Taiwan Province of China', 'Japan', 'South Korea', 'Mongolia', 'Hong Kong S.A.R. of China', 'China']
#
# Latin America and Caribbean
# ['Costa Rica', 'Guatemala', 'Uruguay', 'Brazil', 'Mexico', 'Jamaica', 'Panama', 'Chile', 'El Salvador', 'Colombia', 'Nicaragua', 'Argentina', 'Honduras', 'Peru', 'Ecuador', 'Bolivia', 'Paraguay', 'Dominican Republic', 'Venezuela', 'Haiti']
#
# Middle East and North Africa
# ...

# %%
## add the necessary colum
# define the dictionary of country_regions from above informations
country_regions = {
    'Western Europe': ['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 'Norway', 'Sweden', 'Luxembourg', 'Austria', 'Germany', 'Ireland', 'United Kingdom', 'Malta', 'Cyprus', 'Greece', 'Portugal', 'North Cyprus', 'Belgium', 'France', 'Spain', 'Italy'],
    'North America and ANZ': ['New Zealand', 'Australia', 'Canada', 'United States'],
    'Middle East and North Africa': ['Egypt','Israel', 'Bahrain', 'United Arab Emirates', 'Saudi Arabia', 'Kuwait', 'Libya', 'Morocco', 'Palestinian Territories', 'Iraq', 'Lebanon', 'Jordan', 'Tunisia', 'Yemen', 'Iran', 'Algeria', 'Turkey','Armenia'],
    'Central and Eastern Europe': ['Czech Republic','Tajikistan','Czech Republic', 'Slovenia', 'Kosovo', 'Slovakia', 'Lithuania', 'Estonia', 'Poland', 'Kazakhstan', 'Romania', 'Serbia', 'Latvia', 'Bosnia and Herzegovina', 'Moldova', 'Croatia', 'North Macedonia', 'Albania', 'Georgia', 'Ukraine', 'Hungary', 'Uzbekistan', 'Kyrgyzstan', 'Montenegro', 'Bulgaria', 'Russia'],
    'Latin America and Caribbean': ['Costa Rica', 'Guatemala', 'Uruguay', 'Jamaica', 'El Salvador', 'Colombia', 'Nicaragua', 'Argentina', 'Honduras', 'Peru', 'Bolivia', 'Paraguay', 'Dominican Republic', 'Venezuela', 'Haiti', 'Panama', 'Brazil', 'Chile', 'Mexico', 'Ecuador'],
    'Southeast Asia': ['Singapore', 'Thailand', 'Philippines', 'Vietnam', 'Malaysia', 'Indonesia', 'Laos', 'Cambodia', 'Myanmar'],
    'South Asia':['Nepal', 'Maldives', 'Bangladesh', 'Pakistan', 'Sri Lanka', 'India', 'Afghanistan'],
    'East Asia': ['Taiwan Province of China', 'Japan', 'Hong Kong S.A.R. of China', 'South Korea', 'Mongolia','China'],
    'Sub-Saharan Africa': ['Congo','Mauritius', 'Congo (Brazzaville)', 'Ivory Coast', 'Cameroon', 'Senegal', 'Ghana', 'Niger', 'Gambia', 'Benin', 'South Africa', 'Mozambique', 'Nigeria', 'Mali', 'Uganda', 'Liberia', 'Kenya', 'Namibia', 'Madagascar', 'Togo', 'Zambia', 'Sierra Leone', 'Burundi', 'Tanzania', 'Malawi', 'Lesotho', 'Botswana', 'Rwanda', 'Zimbabwe', 'Swaziland', 'Comoros', 'Ethiopia', 'Mauritania', 'Gabon', 'Guinea', 'Burkina Faso'],
}

#add the condition to match the countries and regions. 
def get_region(country):
    for region, countries in country_regions.items():
        if country in countries:
            return region
    return None

# add the new column "Regional Indicator" in 2022 file
y22.insert(2, 'Regional indicator', y22['Country'].apply(get_region))
y22
# Out:
#      RANK       Country            Regional indicator Happiness score
# 0       1       Finland                Western Europe           7.821  \
# 1       2       Denmark                Western Europe           7.636
# 2       3       Iceland                Western Europe           7.557
# 3       4   Switzerland                Western Europe           7.512
# 4       5   Netherlands                Western Europe           7.415
# ..    ...           ...                           ...             ...
# 138   139      Tanzania            Sub-Saharan Africa           3.702
# 139   140  Sierra Leone            Sub-Saharan Africa           3.574
# 143   144      Zimbabwe            Sub-Saharan Africa           2.995
# 144   145       Lebanon  Middle East and North Africa           2.955
# 145   146   Afghanistan                    South Asia           2.404
#
#     Whisker-high Whisker-low Dystopia (1.83) + residual
# 0          7.886       7.756                      2.518  \
# ...

# %%
y21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
y22.columns
# Out:
# Index(['RANK', 'Country', 'Regional indicator', 'Happiness score',
#        'Whisker-high', 'Whisker-low', 'Dystopia (1.83) + residual',
#        'Explained by: GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
#change the colums name to match with 2021 file
y22 = y22.rename(columns={'Country': 'Country name','Explained by: GDP per capita':'Log GDP per capita', 'Explained by: Social support':'Social support',
       'Explained by: Healthy life expectancy':'Healthy life expectancy',
       'Explained by: Freedom to make life choices':'Freedom to make life choices',
       'Explained by: Generosity':'Generosity', 'Explained by: Perceptions of corruption': 'Perceptions of corruption','Dystopia (1.83) + residual':'Dystopia + residual'})
y22
# Out:
#      RANK  Country name            Regional indicator Happiness score
# 0       1       Finland                Western Europe           7.821  \
# 1       2       Denmark                Western Europe           7.636
# 2       3       Iceland                Western Europe           7.557
# 3       4   Switzerland                Western Europe           7.512
# 4       5   Netherlands                Western Europe           7.415
# ..    ...           ...                           ...             ...
# 138   139      Tanzania            Sub-Saharan Africa           3.702
# 139   140  Sierra Leone            Sub-Saharan Africa           3.574
# 143   144      Zimbabwe            Sub-Saharan Africa           2.995
# 144   145       Lebanon  Middle East and North Africa           2.955
# 145   146   Afghanistan                    South Asia           2.404
#
#     Whisker-high Whisker-low Dystopia + residual Log GDP per capita
# ...

# %%
# Add Year colums to be easy to diffirentciate after marging the flies
y22.insert(loc=0, column='Year', value=2022)
y22
# Out:
#      Year  RANK  Country name            Regional indicator Happiness score
# 0    2022     1       Finland                Western Europe           7.821  \
# 1    2022     2       Denmark                Western Europe           7.636
# 2    2022     3       Iceland                Western Europe           7.557
# 3    2022     4   Switzerland                Western Europe           7.512
# 4    2022     5   Netherlands                Western Europe           7.415
# ..    ...   ...           ...                           ...             ...
# 138  2022   139      Tanzania            Sub-Saharan Africa           3.702
# 139  2022   140  Sierra Leone            Sub-Saharan Africa           3.574
# 143  2022   144      Zimbabwe            Sub-Saharan Africa           2.995
# 144  2022   145       Lebanon  Middle East and North Africa           2.955
# 145  2022   146   Afghanistan                    South Asia           2.404
#
# ...

# %%
# check if there are any misssing values
y22.isnull().sum()
# Out:
# Year                            0
# RANK                            0
# Country name                    0
# Regional indicator              0
# Happiness score                 0
# Whisker-high                    0
# Whisker-low                     0
# Dystopia + residual             0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
# saving a new 2022 dataframe to csv 
y22.to_csv('new2022.csv',index=False)

# %%
# Read saved file and to cheack 
new2022 = pd.read_csv('new2022.csv')
new2022
# Out:
#      Year  RANK  Country name            Regional indicator  Happiness score
# 0    2022     1       Finland                Western Europe            7.821  \
# 1    2022     2       Denmark                Western Europe            7.636
# 2    2022     3       Iceland                Western Europe            7.557
# 3    2022     4   Switzerland                Western Europe            7.512
# 4    2022     5   Netherlands                Western Europe            7.415
# ..    ...   ...           ...                           ...              ...
# 120  2022   139      Tanzania            Sub-Saharan Africa            3.702
# 121  2022   140  Sierra Leone            Sub-Saharan Africa            3.574
# 122  2022   144      Zimbabwe            Sub-Saharan Africa            2.995
# 123  2022   145       Lebanon  Middle East and North Africa            2.955
# 124  2022   146   Afghanistan                    South Asia            2.404
#
# ...

# %%
new2022.columns
# Out:
# Index(['Year', 'RANK', 'Country name', 'Regional indicator', 'Happiness score',
#        'Whisker-high', 'Whisker-low', 'Dystopia + residual',
#        'Log GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# ## working on 2021 dataset

# %%
#check NaN
y21.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
#check the colums name of 2022
y22.columns
# Out:
# Index(['Year', 'RANK', 'Country name', 'Regional indicator', 'Happiness score',
#        'Whisker-high', 'Whisker-low', 'Dystopia + residual',
#        'Log GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#check the colums name of 2021
y21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
#drop the colums to match with 2022 file
y21 = y21.drop(['Standard error of ladder score','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption', 'Ladder score in Dystopia'], axis=1)
y21.head()
# Out:
#   Country name Regional indicator  Ladder score  upperwhisker  lowerwhisker
# 0      Finland     Western Europe         7.842         7.904         7.780  \
# 1      Denmark     Western Europe         7.620         7.687         7.552
# 2  Switzerland     Western Europe         7.571         7.643         7.500
# 3      Iceland     Western Europe         7.554         7.670         7.438
# 4  Netherlands     Western Europe         7.464         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support
# 0                             1.446                         1.106  \
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy
# 0                                  0.741  \
# ...

# %%
#change the colums name to match with 2022 file
y21 = y21.rename(columns={'Ladder score': 'Happiness score','upperwhisker':'Whisker-high','lowerwhisker':'Whisker-low','Explained by: Log GDP per capita':'Log GDP per capita', 'Explained by: Social support':'Social support',
       'Explained by: Healthy life expectancy':'Healthy life expectancy',
       'Explained by: Freedom to make life choices':'Freedom to make life choices',
       'Explained by: Generosity':'Generosity', 'Explained by: Perceptions of corruption': 'Perceptions of corruption' })
y21
# Out:
#     Country name  Regional indicator  Happiness score  Whisker-high
# 0        Finland      Western Europe            7.842         7.904  \
# 1        Denmark      Western Europe            7.620         7.687
# 2    Switzerland      Western Europe            7.571         7.643
# 3        Iceland      Western Europe            7.554         7.670
# 4    Netherlands      Western Europe            7.464         7.518
# ..           ...                 ...              ...           ...
# 144      Lesotho  Sub-Saharan Africa            3.512         3.748
# 145     Botswana  Sub-Saharan Africa            3.467         3.611
# 146       Rwanda  Sub-Saharan Africa            3.415         3.548
# 147     Zimbabwe  Sub-Saharan Africa            3.145         3.259
# 148  Afghanistan          South Asia            2.523         2.596
#
#      Whisker-low  Log GDP per capita  Social support  Healthy life expectancy
# ...

# %%
# Add Year colums to be easy to diffirentciate after marging the flies
y21.insert(loc=0, column='Year', value=2021)
y21
# Out:
#      Year Country name  Regional indicator  Happiness score  Whisker-high
# 0    2021      Finland      Western Europe            7.842         7.904  \
# 1    2021      Denmark      Western Europe            7.620         7.687
# 2    2021  Switzerland      Western Europe            7.571         7.643
# 3    2021      Iceland      Western Europe            7.554         7.670
# 4    2021  Netherlands      Western Europe            7.464         7.518
# ..    ...          ...                 ...              ...           ...
# 144  2021      Lesotho  Sub-Saharan Africa            3.512         3.748
# 145  2021     Botswana  Sub-Saharan Africa            3.467         3.611
# 146  2021       Rwanda  Sub-Saharan Africa            3.415         3.548
# 147  2021     Zimbabwe  Sub-Saharan Africa            3.145         3.259
# 148  2021  Afghanistan          South Asia            2.523         2.596
#
#      Whisker-low  Log GDP per capita  Social support  Healthy life expectancy
# ...

# %%
# Create Rank Colums 
y21.insert(loc=1, column='RANK', value=range(1, 150))
y21
# Out:
#      Year  RANK Country name  Regional indicator  Happiness score
# 0    2021     1      Finland      Western Europe            7.842  \
# 1    2021     2      Denmark      Western Europe            7.620
# 2    2021     3  Switzerland      Western Europe            7.571
# 3    2021     4      Iceland      Western Europe            7.554
# 4    2021     5  Netherlands      Western Europe            7.464
# ..    ...   ...          ...                 ...              ...
# 144  2021   145      Lesotho  Sub-Saharan Africa            3.512
# 145  2021   146     Botswana  Sub-Saharan Africa            3.467
# 146  2021   147       Rwanda  Sub-Saharan Africa            3.415
# 147  2021   148     Zimbabwe  Sub-Saharan Africa            3.145
# 148  2021   149  Afghanistan          South Asia            2.523
#
#      Whisker-high  Whisker-low  Log GDP per capita  Social support
# 0           7.904        7.780               1.446           1.106  \
# ...

# %%
# saving a new 2021 dataframe to csv 
y21.to_csv('new2021.csv',index=False)

# %%
# Read saved file and to cheack 
new2021 = pd.read_csv('new2021.csv')
new2021
# Out:
#      Year  RANK Country name  Regional indicator  Happiness score
# 0    2021     1      Finland      Western Europe            7.842  \
# 1    2021     2      Denmark      Western Europe            7.620
# 2    2021     3  Switzerland      Western Europe            7.571
# 3    2021     4      Iceland      Western Europe            7.554
# 4    2021     5  Netherlands      Western Europe            7.464
# ..    ...   ...          ...                 ...              ...
# 144  2021   145      Lesotho  Sub-Saharan Africa            3.512
# 145  2021   146     Botswana  Sub-Saharan Africa            3.467
# 146  2021   147       Rwanda  Sub-Saharan Africa            3.415
# 147  2021   148     Zimbabwe  Sub-Saharan Africa            3.145
# 148  2021   149  Afghanistan          South Asia            2.523
#
#      Whisker-high  Whisker-low  Log GDP per capita  Social support
# 0           7.904        7.780               1.446           1.106  \
# ...

# %%
new2021.columns
# Out:
# Index(['Year', 'RANK', 'Country name', 'Regional indicator', 'Happiness score',
#        'Whisker-high', 'Whisker-low', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# ## working on 2020 dataset

# %%
#check NaN
y20.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
#check the colums name of 2020
y20.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
#drop the colums to match with 2022 file
y20 = y20.drop(['Standard error of ladder score','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption', 'Ladder score in Dystopia'], axis=1)
y20.head()
# Out:
#   Country name Regional indicator  Ladder score  upperwhisker  lowerwhisker
# 0      Finland     Western Europe        7.8087      7.869766      7.747634  \
# 1      Denmark     Western Europe        7.6456      7.711245      7.579955
# 2  Switzerland     Western Europe        7.5599      7.628528      7.491272
# 3      Iceland     Western Europe        7.5045      7.621347      7.387653
# 4       Norway     Western Europe        7.4880      7.556281      7.419719
#
#    Explained by: Log GDP per capita  Explained by: Social support
# 0                          1.285190                      1.499526  \
# 1                          1.326949                      1.503449
# 2                          1.390774                      1.472403
# 3                          1.326502                      1.547567
# 4                          1.424207                      1.495173
#
#    Explained by: Healthy life expectancy
# 0                               0.961271  \
# ...

# %%
#change the colums name to match with 2022 file
y20 = y20.rename(columns={'Ladder score': 'Happiness score','upperwhisker':'Whisker-high','lowerwhisker':'Whisker-low','Explained by: Log GDP per capita':'Log GDP per capita', 'Explained by: Social support':'Social support',
       'Explained by: Healthy life expectancy':'Healthy life expectancy',
       'Explained by: Freedom to make life choices':'Freedom to make life choices',
       'Explained by: Generosity':'Generosity', 'Explained by: Perceptions of corruption': 'Perceptions of corruption' })
y20
# Out:
#                  Country name  Regional indicator  Happiness score
# 0                     Finland      Western Europe           7.8087  \
# 1                     Denmark      Western Europe           7.6456
# 2                 Switzerland      Western Europe           7.5599
# 3                     Iceland      Western Europe           7.5045
# 4                      Norway      Western Europe           7.4880
# ..                        ...                 ...              ...
# 148  Central African Republic  Sub-Saharan Africa           3.4759
# 149                    Rwanda  Sub-Saharan Africa           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151               South Sudan  Sub-Saharan Africa           2.8166
# 152               Afghanistan          South Asia           2.5669
#
#      Whisker-high  Whisker-low  Log GDP per capita  Social support
# 0        7.869766     7.747634            1.285190        1.499526  \
# ...

# %%
# Add Year colums to be easy to diffirentciate after marging the flies
y20.insert(loc=0, column='Year', value=2020)
y20
# Out:
#      Year              Country name  Regional indicator  Happiness score
# 0    2020                   Finland      Western Europe           7.8087  \
# 1    2020                   Denmark      Western Europe           7.6456
# 2    2020               Switzerland      Western Europe           7.5599
# 3    2020                   Iceland      Western Europe           7.5045
# 4    2020                    Norway      Western Europe           7.4880
# ..    ...                       ...                 ...              ...
# 148  2020  Central African Republic  Sub-Saharan Africa           3.4759
# 149  2020                    Rwanda  Sub-Saharan Africa           3.3123
# 150  2020                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151  2020               South Sudan  Sub-Saharan Africa           2.8166
# 152  2020               Afghanistan          South Asia           2.5669
#
#      Whisker-high  Whisker-low  Log GDP per capita  Social support
# ...

# %%
# Create Rank Colums 
y20.insert(loc=1, column='RANK', value=range(1, 154))
y20
# Out:
#      Year  RANK              Country name  Regional indicator
# 0    2020     1                   Finland      Western Europe  \
# 1    2020     2                   Denmark      Western Europe
# 2    2020     3               Switzerland      Western Europe
# 3    2020     4                   Iceland      Western Europe
# 4    2020     5                    Norway      Western Europe
# ..    ...   ...                       ...                 ...
# 148  2020   149  Central African Republic  Sub-Saharan Africa
# 149  2020   150                    Rwanda  Sub-Saharan Africa
# 150  2020   151                  Zimbabwe  Sub-Saharan Africa
# 151  2020   152               South Sudan  Sub-Saharan Africa
# 152  2020   153               Afghanistan          South Asia
#
#      Happiness score  Whisker-high  Whisker-low  Log GDP per capita
# 0             7.8087      7.869766     7.747634            1.285190  \
# 1             7.6456      7.711245     7.579955            1.326949
# ...

# %%
# saving a new 2020 dataframe to csv 
y20.to_csv('new2020.csv',index=False)

# %%
# Read saved file and to cheack 
new2020 = pd.read_csv('new2020.csv')
new2020
# Out:
#      Year  RANK              Country name  Regional indicator
# 0    2020     1                   Finland      Western Europe  \
# 1    2020     2                   Denmark      Western Europe
# 2    2020     3               Switzerland      Western Europe
# 3    2020     4                   Iceland      Western Europe
# 4    2020     5                    Norway      Western Europe
# ..    ...   ...                       ...                 ...
# 148  2020   149  Central African Republic  Sub-Saharan Africa
# 149  2020   150                    Rwanda  Sub-Saharan Africa
# 150  2020   151                  Zimbabwe  Sub-Saharan Africa
# 151  2020   152               South Sudan  Sub-Saharan Africa
# 152  2020   153               Afghanistan          South Asia
#
#      Happiness score  Whisker-high  Whisker-low  Log GDP per capita
# 0             7.8087      7.869766     7.747634            1.285190  \
# 1             7.6456      7.711245     7.579955            1.326949
# ...

# %%
new2020.columns
# Out:
# Index(['Year', 'RANK', 'Country name', 'Regional indicator', 'Happiness score',
#        'Whisker-high', 'Whisker-low', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# ## Merging the 3 files

# %%
# merge the dataframes vertically using the concat method
merged_df = pd.concat([new2020, new2021,new2022])

# save the merged dataframe to a new CSV file
merged_df.to_csv('Worldhappinessreport2020-2022.csv', index=False)

# %%
# Read saved file and to cheack 
newreport = pd.read_csv('Worldhappinessreport2020-2022.csv')
newreport
# Out:
#      Year  RANK  Country name            Regional indicator  Happiness score
# 0    2020     1       Finland                Western Europe           7.8087  \
# 1    2020     2       Denmark                Western Europe           7.6456
# 2    2020     3   Switzerland                Western Europe           7.5599
# 3    2020     4       Iceland                Western Europe           7.5045
# 4    2020     5        Norway                Western Europe           7.4880
# ..    ...   ...           ...                           ...              ...
# 422  2022   139      Tanzania            Sub-Saharan Africa           3.7020
# 423  2022   140  Sierra Leone            Sub-Saharan Africa           3.5740
# 424  2022   144      Zimbabwe            Sub-Saharan Africa           2.9950
# 425  2022   145       Lebanon  Middle East and North Africa           2.9550
# 426  2022   146   Afghanistan                    South Asia           2.4040
#
# ...

# %%
#check NaN values
newreport.isnull().sum()
# Out:
# Year                            0
# RANK                            0
# Country name                    0
# Regional indicator              0
# Happiness score                 0
# Whisker-high                    0
# Whisker-low                     0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Dystopia + residual             0
# dtype: int64

# %%
newreport.columns
# Out:
# Index(['Year', 'RANK', 'Country name', 'Regional indicator', 'Happiness score',
#        'Whisker-high', 'Whisker-low', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')
